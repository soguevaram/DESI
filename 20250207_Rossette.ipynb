# %% [markdown]
# <style>
# body {
#     font-size: 20pt !important;
# }
#
# .rendered_html {
#     font-size: 20pt !important;
# }
#
# .CodeMirror pre {
#     font-size: 20pt !important;
# }
#
# .output pre {
#     font-size: 20pt !important;
# }
# </style>

# %% [markdown]
# <h2 style="font-size:24pt"> Proyecto DESI</h2>
#
# <h2 style="font-size:24pt"> Julio 2, 2025</h2>
#
# <p style="font-size:16pt">
# Creación de gráficas de distribuciones de ra,dec en un rango de z para todas las rosetas para el tipo de galaxia LRG (Luminous Red Galaxy)
# </p>

# %% [markdown]
# ## Data

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table

# %%
# original files are found here https://data.desi.lbl.gov/public/edr/vac/edr/lss/v2.0/LSScats/clustering/
data = Table.read("https://data.desi.lbl.gov/public/edr/vac/edr/lss/v2.0/LSScats/clustering/LRG_N_clustering.dat.fits")
rand = Table.read("https://data.desi.lbl.gov/public/edr/vac/edr/lss/v2.0/LSScats/clustering/LRG_N_0_clustering.ran.fits")

# %%
data
# Out:
# <Table length=54880>
#         RA                DEC              TARGETID     ...           NZ                WEIGHT_FKP
#        deg                deg                           ...       h3 / Mpc3
#      float64            float64             int64       ...        float64               float64
# ------------------ ------------------ ----------------- ... ---------------------- -------------------
# 218.17242054901192  52.54211577658059 39633286401623197 ...  0.0006073340474539246  0.1455520198534496
# 217.94384586244482  53.30190604099312 39633297378116593 ...  0.0005823912580269674 0.15084542533972659
# 217.94491107615283  53.25773967666818 39633297378116603 ...  0.0005723615213970424 0.15308410280969617
# 217.94818897430363 53.184679060489565 39633297378116632 ...  0.0005369919189708607  0.1615383650856205
#  215.8531155009324 54.149169507535355 39633311697469641 ...  0.0006366829495309179  0.1397804201853648
# 214.53697625730607  52.53526414070296 39633286363874909 ...  0.0005823912580269674 0.15084542533972659
# 215.82829092301523  51.04952001518059 39633263869822941 ...  0.0006106036532175123 0.14488555312656437
# 214.11604348164602 53.561400062885134 39633300955858767 ...  0.0006073340474539246  0.1455520198534496
# 215.82456704591593   51.0461358780409 39633263869822905 ...  0.0006106036532175123 0.14488555312656437
# 216.11050201565695 53.433721707535454 39633300976829417 ...  0.0007242712797402853 0.12498917450484462
# 215.99725929287902 53.025472428568726 39633293716491780 ... 5.9370222311395755e-05  0.6353792046182113
# 215.39083024649833  52.07294551632719 39633278948345878 ... 0.00042618922305278896  0.1953324009783564
#                ...                ...               ... ...                    ...                 ...
#  189.0402534170364  60.28834879505307 39633390168703081 ...  0.0007982518636535506 0.11473445525619816
# 189.03725442614285 60.294179893582225 39633390168703055 ...  0.0007365189099627642 0.12316671624379881
#  190.9037385799944 60.194326524478505 39633390181288330 ...  0.0005613841910631427  0.1556117057517016
#   192.944477726868 60.927671825496965 39633399131931477 ... 0.00014839258087788972 0.41078905010633954
# 192.36798997285587 60.552163819239055 39633393192797862 ...  0.0005369919189708607  0.1615383650856205
#  193.3151448755688  61.90474734526316 39633410720793105 ...  0.0003767415448896098 0.21544643941305056
# 192.91778796198292  62.54612467495481 39633416366328748 ...  0.0006576102792991648  0.1359368301360722
# 189.04247099253493  60.22680864196039 39633390168703101 ...  0.0007982518636535506 0.11473445525619816
# 189.00271886066312 60.233090632403716 39633390164512201 ...  0.0005346154933450218  0.1621399955636538
#  188.9844966206087  60.26145140435589 39633390164512086 ...  0.0007242712797402853 0.12498917450484462
#  188.9691855847895  60.27410386932701 39633390164512007 ...  0.0007242712797402853 0.12498917450484462
# 189.96508728150877 61.990986665423605 39633410691435218 ...  0.0003767415448896098 0.21544643941305056

# %%
set(data['ROSETTE_NUMBER'])
# Out:
# {3, 6, 7, 11, 12, 13, 14, 15, 18, 19}

# %% [markdown]
# ## Functions

# %%
conditions = list()
for i in set(data['ROSETTE_NUMBER']):
    number_rosette = data['ROSETTE_NUMBER'] == i
    conditions.append(number_rosette)

# %%
for i in conditions: 
    plt.scatter(data['RA'][i], data['DEC'][i], s=0.1)
    plt.axis('equal')

# %%
def rosette_all(rosette):
    plot = plt.scatter(data['RA'][rosette], data['DEC'][rosette], s=0.1)
    plt.axis('equal')

# %% [markdown]
# n = The values of the histogram bins\
# bins = The edges of the bins\
# patches = Container of individual artists used to create the histogram or list of such containers if there are multiple input datasets.

# %%
def max_value(rosette):

    n, bins, patches = plt.hist(data['Z'][rosette].flat,bins=10)
    pos_max_bin = np.argmax(n)
    bin_center = (bins[pos_max_bin] + bins[pos_max_bin+1]) / 2
    left = bin_center - 0.03
    right = bin_center + 0.03
    
    return (left, bin_center, right)

# %%
def rosette(rosette,left,right):
    bounds = (data['Z']>left) & (data['Z']<right)
    plt.scatter(data['RA'][rosette&bounds], data['DEC'][rosette&bounds], s=5)
    plt.axis('equal')

# %%
set(data['ROSETTE_NUMBER'])
# Out:
# {3, 6, 7, 11, 12, 13, 14, 15, 18, 19}

# %% [markdown]
# ## Rosette 3

# %%
rosette_all(conditions[0])

# %%
max_value_3 = max_value(conditions[0])

# %%
rosette(conditions[0],max_value_3[0],max_value_3[2])

# %% [markdown]
# ## Rosette 6

# %%
rosette_all(conditions[1])

# %%
max_value_6 = max_value(conditions[1])

# %%
rosette(conditions[1],max_value_6[0],max_value_6[2])

# %% [markdown]
# ## Rosette 7

# %%
rosette_all(conditions[2])

# %%
max_value_7 = max_value(conditions[2])

# %%
rosette(conditions[2],max_value_7[0],max_value_7[2])

# %% [markdown]
# ## Rosette 11

# %%
rosette_all(conditions[3])

# %%
max_value_11 = max_value(conditions[3])

# %%
rosette(conditions[3],max_value_11[0],max_value_11[2])

# %% [markdown]
# ## Rosette 12

# %%
rosette_all(conditions[4])

# %%
max_value_12 = max_value(conditions[4])

# %%
rosette(conditions[4],max_value_12[0],max_value_12[2])

# %% [markdown]
# ## Rosette 13

# %%
rosette_all(conditions[5])

# %%
max_value_13 = max_value(conditions[5])

# %%
rosette(conditions[5],max_value_13[0],max_value_13[2])

# %% [markdown]
# ## Rosette 14

# %%
rosette_all(conditions[6])

# %%
max_value_14 = max_value(conditions[6])

# %%
rosette(conditions[6],max_value_14[0],max_value_14[2])

# %% [markdown]
# ## Rosette 15

# %%
rosette_all(conditions[7])

# %%
max_value_15 = max_value(conditions[7])

# %%
rosette(conditions[7],max_value_15[0],max_value_15[2])

# %% [markdown]
# ## Rosette 18

# %%
rosette_all(conditions[8])

# %%
max_value_18 = max_value(conditions[8])

# %%
rosette(conditions[8],max_value_18[0],max_value_18[2])

# %% [markdown]
# ## Rosette 19

# %%
rosette_all(conditions[9])

# %%
max_value_19 = max_value(conditions[9])

# %%
rosette(conditions[9],max_value_19[0],max_value_19[2])
